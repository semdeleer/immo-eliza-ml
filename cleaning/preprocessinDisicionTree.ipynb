# %% [markdown]
# ## Import

# %%
import numpy as numpy
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

# %%
url = r"..\data\raw\clean_house.csv"
house = pd.read_csv(url, sep=",")

# %%
def tranform_label_encoder(df, clist):
    for column in clist:
        le = LabelEncoder()
        df[column] = le.fit_transform(df[column])
    return df

# %%
house.head()
# Out:
#    property_id      locality_name  postal_code   latitude  longitude  \
# 0     11157483              ronse         9600  50.741809   3.607601
# 1     11156843          merelbeke         9820  51.019250   3.760957
# 2     11161362              forêt         4870  50.563966   5.675489
# 3     11153591          ottignies         1340  50.671784   4.575929
# 4     11128275  antwerpen merksem         2170  51.243743   4.443372
#
#   property_type    property_subtype     price type_of_sale  number_of_rooms  \
# 0         HOUSE               HOUSE  245000.0  BUY_REGULAR              NaN
# 1         HOUSE               HOUSE  315000.0  BUY_REGULAR              NaN
# 2         HOUSE               HOUSE  325000.0  BUY_REGULAR              NaN
# 3         HOUSE               HOUSE  395000.0  BUY_REGULAR              NaN
# 4         HOUSE  MIXED_USE_BUILDING  399900.0  BUY_REGULAR              NaN
#
#    ...  terrace terrace_area  garden  garden_area  surface_of_good  \
# 0  ...      1.0         13.0     1.0        161.0            250.0
# 1  ...      1.0         23.0     NaN          NaN             77.0
# 2  ...      1.0         16.0     1.0        420.0            572.0
# 3  ...      1.0         37.0     1.0         76.0            165.0
# 4  ...      NaN          NaN     NaN          NaN             65.0
#
#    number_of_facades  swimming_pool  state_of_building  \
# 0                2.0            0.0               GOOD
# 1                2.0            NaN               GOOD
# 2                3.0            NaN             AS_NEW
# 3                2.0            NaN               GOOD
# 4                2.0            0.0               GOOD
#
#                     main_city         province
# 0                       ronse  oost-vlaanderen
# 1                   merelbeke  oost-vlaanderen
# 2                       trooz             luik
# 3  ottignies-louvain-la-neuve    waals-brabant
# 4                   antwerpen        antwerpen
#
# [5 rows x 25 columns]

# %%
house = house[["property_subtype", "price", "surface_of_good", "swimming_pool", "state_of_building"]]
house = tranform_label_encoder(house, ["state_of_building"])

# %%
X = house.drop(columns="property_subtype")
y = house.property_subtype

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)
clf_entropy = DecisionTreeClassifier(criterion="entropy", random_state=100, max_depth=3, min_samples_leaf=5)
clf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=100)

# %%
y_pred_en = clf_entropy.predict(X_test)
print(y_pred_en)
# Out:
# ['HOUSE' 'HOUSE' 'HOUSE' ... 'HOUSE' 'HOUSE' 'HOUSE']

# %%
print(f"Accuracy is: {accuracy_score(y_test, y_pred_en)*100}")
# Out:
# Accuracy is: 77.59578824217608

# %%
print(X_train.head())
[2]
# Out:
#          price  surface_of_good  swimming_pool  state_of_building
# 4064  499000.0           2523.0            0.0                  4
# 1909  240000.0             80.0            NaN                  4
# 8615  149000.0            165.0            NaN                  4
# 4063  325000.0             84.0            NaN                  1
# 4681  285000.0            800.0            NaN                  5
# [2]

# %%
predicttf = [[240000.0, 100.0, 1.0, 4]]

cl = clf_entropy.predict(predicttf)
print(cl)
# Out:
# ['HOUSE']
# c:\Users\semde\PythonEnviroments\BeCodeEnv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
